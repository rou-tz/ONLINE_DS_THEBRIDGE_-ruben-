# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios Python Basics II

# %% [markdown]
# ## Ejercicio 1
# * Crea dos variables numericas: un `int` y un `float`
# * Comprueba sus tipos
# * Sumalas en otra nueva
# * ¿De qué tipo es la nueva variable?
# * Elimina las variables creadas

# %%
var_int = 12
var_float = 4.50
var_sum = var_int + var_float
print(var_sum)
print(type(var_sum))
del var_float, var_int, var_sum
# Out:
# 16.5
# <class 'float'>

# %% [markdown]
# ## Ejercicio 2
# Escribe un programa para pasar de grados a radianes. Hay que usar `input`. Recuerda que la conversión se realiza mediante
#
# $$radianes = grados*(pi/180)$$

# %%
import math
grados = (float(input("Introduce los grados")))
radianes = grados *(math.pi/180)
print(f"El resultado es {radianes}")
# Out:
# El resultado es 0.7853981633974483

# %% [markdown]
# ## Ejercicio 3
# Escribe un programa que calcule el area de un paralelogramo (base x altura). También con `input`

# %%
base = float(input("Introduce la base").replace(",","."))
altura = float(input("Introduce la altura").replace(",","."))

area = base * altura

print(f"El area es {area}")
# Out:
# El area es 12.0

# %% [markdown]
# ## Ejercicio 4
# Tenemos las siguientes variables:
#
# ```Python
# A = 4
# B = "Text"
# C = 4.1
# ```
#
# Comprueba:
# 1. Si A y B son equivalentes
# 2. Si A y C NO son equivalentes
# 3. Si A es mayor que C
# 4. Si C es menor o igual que A
# 5. Si B NO es equivalente a C

# %%
A = 4
B = "Text"
C = 4.1

print(A == B)
print(A != C)
print(A > C)
print(C < A)
print(B != C)
# Out:
# False
# True
# False
# False
# True

# %%
if A == B:
    print("Son iguales")
else:
    print("No lo son")
# Out:
# No lo son

# %% [markdown]
# ## Ejercicio 5
# Crea un programa donde se recojan dos inputs del usuario, y el output del programa sea si esos inputs son iguales o no

# %%
var_1 = input("Introduzca un valor")
var_2 = input("Introduzca una palabra")

print(var_1 == var_2)
# Out:
# False

# %% [markdown]
# ## Ejercicio 6
# Mismo programa que en 5, pero en esta ocasión tienen que ser tres inputs y dos salidas. Una de las salidas que nos indique si todos son iguales, y la otra si al menos dos inputs sí que lo son

# %%
var_1 = input("Introduzca un valor")
var_2 = input("Introduzca una palabra")
var_3 = input("Introduzca un ultimo valor")

print("Son iguales", var_1 == var_2 and var_2 == var_3)
print("Hay dos iguales?", var_1 == var_2 or var_2 == var_3 or var_1 == var_3 )
# Out:
# Son iguales True
# Hay dos iguales? True

# %% [markdown]
# ## Ejercicio 7
# Crea un programa que recoja dos inputs. Tiene que comprobar si su suma es igual, superior o inferior a 10, cada condición por separado

# %%
num_1 = float(input("Introduzca un valor").replace(",","."))
num_2 = float(input("Introduzca otro valor").replace(",","."))
print((num_1 + num_2) == 10)
print((num_1 + num_2) > 10)
print((num_1 + num_2) < 10)
# Out:
# False
# False
# True

# %% [markdown]
# ## Ejercicio 8
# Razona sin ejecutar código el output que obtendremos de las siguientes sentencias
# 1. True and True and False
# 2. not ((True or False) and (True or False))
# 3. (False or False or False or True) and False
# 4. not False and True and not True
#
# Compruébalo después con python

# %% [markdown]
# 1. False
# 2. not (True) and (True) = False and True = False
# 3. True and False = False
# 4. True and True and False = False

# %% [markdown]
# 1. False, porque es un and y hay un False por lo tanto no se cumple
# 2. False, se esta haciendo un not True and True, que seria un False and True por lo tanto es False
# 3. False, el parentesis seria True pero al compararlo con and False, da False
# 4. False, es True and True and False por lo tanto es False

# %%
print(True and True and False)
print(not((True or False) and (True or False)))
print((False or False or False or True) and False)
print(not True and True and not True)
# Out:
# False
# False
# False
# False

# %% [markdown]
# ## Ejercicio 9
# Para este ejercicio vamos a poner en práctica [las funciones built in](https://docs.python.org/3/library/functions.html).
#
# 1. Calcula el máximo de la lista: [4, 6, 8, -1]
# 2. Suma todos los elementos de la lista anterior
# 3. Redondea este float a 3 dígitos decimales: 63.451256965
# 4. Valor absoluto de: -74

# %%
lista = [4, 6, 8, -1]
print(max(lista))
# Out:
# 8

# %%
print(sum(lista))
# Out:
# 17

# %%
print(round(63.451256965, 3))
# Out:
# 63.451

# %%
print(abs(-74))
# Out:
# 74

# %% [markdown]
# ## Ejercicio 10
# Para el siguiente string se pide imprimir por pantalla los siguientes casos
#
#     "Lo primero de todo, cómo están los máquinas"
#
# 1. Pasarlo todo a mayúsculas
# 2. Pasarlo todo a minúsculas
# 3. Pasar a mayúsculas solo las iniciales de las palabras
# 4. Crea una lista dividiendolo por sus espacios
# 5. Sustituye las comas `,` por puntos y comas `;`
# 6. Elimina las `a` minúsculas

# %%
frase = "Lo primero de todo, cómo están los máquinas"
print(frase.upper())
print(frase.lower())
print(frase.capitalize())
print(frase.split(" "))
print(frase.replace(",",";"))
print(frase.replace("a" and "á",""))
# Out:
# LO PRIMERO DE TODO, CÓMO ESTÁN LOS MÁQUINAS
# lo primero de todo, cómo están los máquinas
# Lo primero de todo, cómo están los máquinas
# ['Lo', 'primero', 'de', 'todo,', 'cómo', 'están', 'los', 'máquinas']
# Lo primero de todo; cómo están los máquinas
# Lo primero de todo, cómo estn los mquinas

# %% [markdown]
# ## Ejercicio 11
# 1. Crea una lista con 3 elementos numéricos
# 2. Añade un cuarto elemento
# 3. Calcula la suma de todos
# 4. Elimina el segundo elemento de la lista
# 5. Añade otro elemento en la posicion 3 de la lista
# 6. Crea otra lista con 4 elementos y concaténala a la que ya tenías.

# %%
lista_11 = [1, 4, 7]
lista_11.append(9)
print(lista_11)
print(sum(lista_11))
lista_11.pop(1)
print(lista_11)
lista_11.insert(2,3)
print(lista_11)
otra_lista = [2, 5, 6, 8]
print(lista_11 + otra_lista)
# Out:
# [1, 4, 7, 9]
# 21
# [1, 7, 9]
# [1, 7, 3, 9]
# [1, 7, 3, 9, 2, 5, 6, 8]
