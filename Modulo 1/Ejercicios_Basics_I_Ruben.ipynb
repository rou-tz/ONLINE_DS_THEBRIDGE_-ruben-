# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios Python Basics I

# %% [markdown]
# ## Ejercicio 0
# Imprime por pantalla esta cita con el siguiente formato
#
# ![imagen](./img/frase_Einstein.PNG)

# %%
print("¿Por qué esta magnífica tecnología científica,\n\tque ahora ahorra trabajo y nos hace la vida mas fácil,\n\t\tnos aporta tan poca felicidad?\n\t\t\tLa respuesta es está, simplemente: porque aún no hemos aprendido a usarla con tino.\n\"Albert Einstein\"")
# Out:
# ¿Por qué esta magnífica tecnología científica,
# 	que ahora ahorra trabajo y nos hace la vida mas fácil,
# 		nos aporta tan poca felicidad?
# 			La respuesta es está, simplemente: porque aún no hemos aprendido a usarla con tino.
# "Albert Einstein"

# %% [markdown]
# ## Ejercicio 1
# 1. Escribe el nombre de la calle de tu domicilio en una variable
# 2. Escribe el numero de la calle en otra
# 3. Ciudad en una tercera
# 4. Codigo postal en la cuarta variable
# 5. Imprime las 4 variables concatenadas por pantalla
# 6. Crea una quinta variable que concatene todas ellas
# 7. Imprímela por pantalla

# %%
calle = "Calle San Marcos"
numero = 7
ciudad = "Bilbao"
codigo_postal = 48001
print(calle, numero, ciudad, codigo_postal)
domicilio = calle + " " + str(numero) + " " + ciudad  + " " + str(codigo_postal)
print(domicilio)
# Out:
# Calle San Marcos 7 Bilbao 48001
# Calle San Marcos 7 Bilbao 48001

# %% [markdown]
# ## Ejercicio 2
# Repite el ejercicio 1, pero pidiendo estos datos al usuario mediante un input(), imprimiendo a continuación la dirección completa

# %%
print("Introduce tu calle")
calle = input()
print("Introduce el numero de portal")
numero = input()
print("¿De qué ciudad?")
ciudad = input()
print("¿Cuál es el código postal?")
codigo_postal = input()

domicilio = calle + " " + str(numero) + " " + ciudad  + " " + str(codigo_postal)
print(f"Tu domicilio es {domicilio}")
# Out:
# Introduce tu calle
# Introduce el numero de portal
# ¿De qué ciudad?
# ¿Cuál es el código postal?
#  Tu domicilio es San Marcos 3 Bilbao 48001

# %% [markdown]
# ## Ejercicio 3
# ¿Qué variables están mal escritas y por qué? Realiza primero tu hipótesis y luego ejecuta las variables para comprobarlo. En ese orden :)
#
#
# 1. mi_variable = "Economía"
# 2. otra_var = "Ejercicio
# 3. True = "Ejercicio"
# 4. mi variab1e = "Alpha"
# 5. import = 40
# 6. 81mi_variable = "Agua"
# 7. mi_variable10 = 6

# %% [markdown]
# 1. Esta bien
# 2. Faltan las comillas del final
# 3. True no puede ser el nombre de la variable
# 4. Las variables no pueden tener espacios
# 5. import es una palabra dedicada no puede ser el nombre de una variable
# 6. las variables no pueden empezar por un numero
# 7. Esta bien

# %%
mi_variable10 = 6

# %% [markdown]
# ## Ejercicio 4
# Realiza un conversor de grados Celsius a Fahrenheit. El conversor tiene que recibir el input del usuario y devolver la conversión.
#
# La conversión de grados sigue la siguiente fórmula: F = C × (9 / 5) + 32

# %%
print("Introduce la temeperatura en Celsius")
grados_celsius = int(input())
grados_farenheit = grados_celsius * (9/5) + 32
print(f"La temeperatura en Farenheit es {grados_farenheit}")
# Out:
# Introduce la temeperatura en Celsius
# La temeperatura en Farenheit es 93.2

# %% [markdown]
# ## Ejercicio 5
# Comenta  el Ejercicio 4. Pon un comentario multilinea y haz comentarios de cada linea de código

# %%
#Vamos a hacer un conversor de grados Celsius a Farenheit
print("Introduce la temeperatura en Celsius")
#Primero pediremos al usuario que introduzca un valor, que pasaremos a int y lo guardamos en grados_celsius
grados_celsius = int(input())

"""
Ahora hacemos la conversion con la formula
"""
grados_farenheit = grados_celsius * (9/5) + 32
#Finalmente mostramos la variable grados_farenheit en la que hemos guardado el resultado de la operación
print(f"La temeperatura en Farenheit es {grados_farenheit}")
# Out:
# Introduce la temeperatura en Celsius
# La temeperatura en Farenheit es 46.4
